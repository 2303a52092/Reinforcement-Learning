# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52092/Reinforcement-Learning/blob/main/lab_Assignment_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
import numpy as np

# Get input from user
env_name = input("Enter environment (CartPole/MountainCar/FrozenLake): ")
episodes = int(input("Enter number of episodes: "))

# Convert user input to Gymnasium environment name
if env_name.lower() == "cartpole":
    env_name = "CartPole-v1"
elif env_name.lower() == "mountaincar":
    env_name = "MountainCar-v0"
elif env_name.lower() == "frozenlake":
    env_name = "FrozenLake-v1"
else:
    print("Invalid environment!")
    exit()

# Create environment
env = gym.make(env_name)

rewards = []

for episode in range(episodes):

    state, info = env.reset()
    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Select random action
        action = env.action_space.sample()

        # Perform action
        next_state, reward, terminated, truncated, info = env.step(action)

        total_reward += reward
        state = next_state

    rewards.append(total_reward)

    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate average reward
average_reward = np.mean(rewards)

print("\n----- Final Results -----")
print("Total Reward =", sum(rewards))
print("Average Reward =", average_reward)

env.close()
